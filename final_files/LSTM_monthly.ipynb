# %%
import pandas as pd
data = pd.read_csv('new_data.csv')
data
# Out:
#         Vintage Credit Status  Quantity   GSID  \
# 0          2018       Retired     29625   5314
# 1          2018       Retired      7500   5314
# 2          2021       Retired        20  10967
# 3          2021       Retired       178   5801
# 4          2021       Retired         1   5801
# ...         ...           ...       ...    ...
# 102499     2007       Retired       455    338
# 102500     2007       Retired     32039    338
# 102501     2007       Retired      7961    338
# 102502     2007       Retired      8000    338
# 102503     2007       Retired      1000    338
#
#                                              Project Name  \
# 0       GS5304 MKOPA Solar Lighting Programme of Activ...
# 1       GS5304 MKOPA Solar Lighting Programme of Activ...
# 2       Community Carbon Efficient Cooking Programme-VPA1
# 3       African Biogas Carbon Programme (ABC) - Kenya ...
# 4       African Biogas Carbon Programme (ABC) - Kenya ...
# ...                                                   ...
# 102499                                *Te Apiti Wind Farm
# 102500                                *Te Apiti Wind Farm
# 102501                                *Te Apiti Wind Farm
# 102502                                *Te Apiti Wind Farm
# 102503                                *Te Apiti Wind Farm
#
#                         Project Developer      Country Product Type  \
# 0                Natural Capital Partners        Kenya          VER
# 1                Natural Capital Partners        Kenya          VER
# 2                          UpEnergy Group       Uganda          VER
# 3       AFRICA BIOENERGY PROGRAMS LIMITED        Kenya          VER
# 4       AFRICA BIOENERGY PROGRAMS LIMITED        Kenya          VER
# ...                                   ...          ...          ...
# 102499                Meridian Energy Ltd  New Zealand          VER
# 102500                Meridian Energy Ltd  New Zealand          VER
# 102501                Meridian Energy Ltd  New Zealand          VER
# 102502                Meridian Energy Ltd  New Zealand          VER
# 102503                Meridian Energy Ltd  New Zealand          VER
#
#                         Project Type  \
# 0        Solar Thermal - Electricity
# 1        Solar Thermal - Electricity
# 2       Energy Efficiency - Domestic
# 3                      Biogas - Heat
# 4                      Biogas - Heat
# ...                              ...
# 102499                          Wind
# 102500                          Wind
# 102501                          Wind
# 102502                          Wind
# 102503                          Wind
#
#                                               Methodology  ... Issuance Date  \
# 0       AMS-III.AR. Substituting fossil fuel based lig...  ...    2023-03-30
# 1       AMS-III.AR. Substituting fossil fuel based lig...  ...    2023-03-30
# 2                                         GS TPDDTEC v3.1  ...    2023-03-24
# 3                                         GS TPDDTEC v 1.  ...    2023-03-09
# 4                                         GS TPDDTEC v 1.  ...    2023-03-09
# ...                                                   ...  ...           ...
# 102499                                                NaN  ...    2008-04-29
# 102500                                                NaN  ...    2008-04-29
# 102501                                                NaN  ...    2008-04-29
# 102502                                                NaN  ...    2008-04-29
# 102503                                                NaN  ...    2008-04-29
#
#         Retirement Date Monitoring Period Start Monitoring Period End  \
# 0            2023-03-31              2018-01-01            2019-12-31
# 1            2023-03-31              2018-01-01            2019-12-31
# 2            2023-04-06              2021-01-01            2021-11-30
# 3            2023-03-27              2021-05-01            2022-04-30
# 4            2023-04-05              2021-05-01            2022-04-30
# ...                 ...                     ...                   ...
# 102499       2009-03-30              2007-01-01            2007-12-31
# 102500       2009-11-02              2007-01-01            2007-12-31
# 102501       2009-03-30              2007-01-01            2007-12-31
# 102502       2009-06-23              2007-01-01            2007-12-31
# 102503       2008-07-01              2007-01-01            2007-12-31
#
#                                      Serial Number  \
# 0          GS1-1-KE-GS5314-2-2018-24143-7501-37125
# 1              GS1-1-KE-GS5314-2-2018-24143-1-7500
# 2       GS1-1-UG-GS10967-16-2021-24092-10686-10705
# 3           GS1-1-KE-GS5801-4-2021-23924-1840-2017
# 4             GS1-1-KE-GS5801-4-2021-23924-589-589
# ...                                            ...
# 102499          GS1-1-NZ-338-12-2007-3-49001-49455
# 102500          GS1-1-NZ-338-12-2007-3-16962-49000
# 102501           GS1-1-NZ-338-12-2007-3-9001-16961
# 102502            GS1-1-NZ-338-12-2007-3-1001-9000
# 102503               GS1-1-NZ-338-12-2007-3-1-1000
#
#                                                      Note  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       Gold Standard Marketplace Order GSM18350 for R...
# ...                                                   ...
# 102499                              Essent Retail Energie
# 102500  green gas sales until september 2009; Essent R...
# 102501                              Essent Retail Energie
# 102502                                                NaN
# 102503                                                NaN
#
#        Eligible for CORSIA? Retired for CORSIA? CORSIA Authorisation  \
# 0                        No                  No       Not Applicable
# 1                        No                  No       Not Applicable
# 2                        No                  No       Not Applicable
# 3                        No                  No       Not Applicable
# 4                        No                  No       Not Applicable
# ...                     ...                 ...                  ...
# 102499                   No                  No       Not Applicable
# 102500                   No                  No       Not Applicable
# 102501                   No                  No       Not Applicable
# 102502                   No                  No       Not Applicable
# 102503                   No                  No       Not Applicable
#
#        Aeroplane Operator Name
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 102499                     NaN
# 102500                     NaN
# 102501                     NaN
# 102502                     NaN
# 102503                     NaN
#
# [102504 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['Vintage', 'Credit Status', 'Quantity', 'GSID', 'Project Name',
#        'Project Developer', 'Country', 'Product Type', 'Project Type',
#        'Methodology', 'Programme of Activities', 'POA GSID', 'Issuance Date',
#        'Retirement Date', 'Monitoring Period Start', 'Monitoring Period End',
#        'Serial Number', 'Note', 'Eligible for CORSIA?', 'Retired for CORSIA?',
#        'CORSIA Authorisation', 'Aeroplane Operator Name'],
#       dtype='object')

# %%
important_data = data[['Issuance Date', 'Quantity']]
important_data
# Out:
#        Issuance Date  Quantity
# 0         2023-03-30     29625
# 1         2023-03-30      7500
# 2         2023-03-24        20
# 3         2023-03-09       178
# 4         2023-03-09         1
# ...              ...       ...
# 102499    2008-04-29       455
# 102500    2008-04-29     32039
# 102501    2008-04-29      7961
# 102502    2008-04-29      8000
# 102503    2008-04-29      1000
#
# [102504 rows x 2 columns]

# %%
import chardet

with open('temp.csv', 'rb') as f:
    contents = f.read()
    detected_encoding = chardet.detect(contents)['encoding']
    print (detected_encoding)
    decoded_contents = contents.decode(detected_encoding)
decoded_contents
# Out:
# Windows-1252
# '"Date Issued","Project ID","Project Name","Project Developer","Project Type","Project Methodology/Protocol","Methodology/Protocol Version","Verified Removal","ARB Eligible","CORSIA Qualified","Vintage","Total Credits Issued","Credits Issued to Project","Credits Issued to Buffer Pool","Project Site Location","Project Site State","Project Site Country","Sustainable Development Goal(s)","Project VVB","Project Website","Documents",\r\n"03/16/2023","ACR814","Tradewater International - Thailand 1.0","Tradewater, LLC","Ozone Depleting Substances","Destruction of Ozone Depleting Substances (ODS) from International Sources","Version 1.0","","No","No","2023","113973","113973","0","965 Moo 2 Soi 3B Bangpoo Industrial Estate, Sukhumvit Rd Bangpoo Mai","Samut Prakan","TH","09: Industry, Innovation and Infrastructure;12: Responsible Consumption and Production;13: Climate Action","GHD Limited","","View",\r\n"02/23/2023","ACR826","Tradewater ODS 48","Tradewater, LLC","Ozone Depleting Substances","ARB Compliance Offset Protocol: Destruction of U.S. Ozone Depleting Substances Banks","November 14, 2014","","Yes","No","2023","132823","132823","0","Bowling Green","OHIO","US","09: Industry, Innovation and Infrastructure;12: Responsible Consumption and Production;13: Climate Action","SES, Inc.","","View",\r\n"10/28/2022","ACR742","Advanced Refrigeration - ARS2021001","Therm Solutions Inc.","Industrial Process Emissions","Advanced Refrigeration Systems","Version 2.1","","No","No","2022","6805","6805","0","18 Winslow Gate Road, Poughkeepsie","NEW YORK","US","09: Industry, Innovation and Infrastructure;11: Sustainable Cities and Communities;12: Responsible Consumption and Production;13: Climate Action","First Environment, Inc.","","View",\r\n"02/08/2023","ACR815","Advanced Refrigeration - ARS2022001","Therm Solutions Inc.","Industrial Process Emissions","Advanced Refrigeration Systems","Version 2.1","","No","No","2022","19002","19002","0","543 12th St Dr NW, Hickory, NC 28601, USA","NORTH CAROLINA","US","09: Industry, Innovation and Infrastructure;11: Sustainable Cities and Communities;12: Responsible Consumption and Production;13: Climate Action","Ruby Canyon Environment","","View",\r\n"01/17/2023","ACR674","Affinity Mine Methane Incineration Project","Keyrock Energy LLC","Coal Mine Methane","ARB Compliance Offset Protocol: Mine Methane Capture Projects","April 25, 2014","","Yes","No","2022","41618","41618","0","Crab Orchard","WEST VIRGINIA","US","09: Industry, Innovation and Infrastructure;13: Climate Action","Dillon Consulting Limited","","View",\r\n"11/21/2022","ACR566","Anew - 100-Mile Wilderness  Forestry Project","Blue Source","Forest Carbon","Improved Forest Management (IFM) on Non-Federal U.S. Forestlands","Version 1.3","","No","No","2022","11942","11942","0","Northern Maine","MAINE","US","06: Clean Water and Sanitation;13: Climate Action;15: Life on Land","","","View",\r\n"11/21/2022","ACR566","Anew - 100-Mile Wilderness  Forestry Project","Blue Source","Forest Carbon","Improved Forest Management (IFM) on Non-Federal U.S. Forestlands","Version 1.3","Yes","No","No","2022","9223","9223","0","Northern Maine","MAINE","US","06: Clean Water and Sanitation;13: Climate Action;15: Life on Land","Ruby Canyon Environment","","View",\r\n"04/04/2023","ACR632","Anew - Eagle Mountain Forestry Project","Northeast Wilderness Trust","Forest Carbon","Improved Forest Management (IFM) on Non-Federal U.S. Forestlands","Version 1.3","","No","No","2022","8007","8007","0","New York, New Hampshire, Vermont, Maine","NEW YORK","US","06: Clean Water and Sanitation;13: Climate Action;15: Life on Land","","newildernesstrust.org","View",\r\n"04/04/2023","ACR632","Anew - Eagle Mountain Forestry Project","Northeast Wilderness Trust","Forest Carbon","Improved Forest Management (IFM) on Non-Federal U.S. Forestlands","Version 1.3","Yes","No","No","2022","3145","3145","0","New York, New Hampshire, Vermont, Maine","NEW YORK","US","06: Clean Water and Sanitation;13: Climate Action ...

# %%
acr_data = pd.read_csv('temp.csv', encoding='cp1252')
acr_data.head()
# Out:
#   Date Issued Project ID                                Project Name  \
# 0  03/16/2023     ACR814     Tradewater International - Thailand 1.0
# 1  02/23/2023     ACR826                           Tradewater ODS 48
# 2  10/28/2022     ACR742         Advanced Refrigeration - ARS2021001
# 3  02/08/2023     ACR815         Advanced Refrigeration - ARS2022001
# 4  01/17/2023     ACR674  Affinity Mine Methane Incineration Project
#
#       Project Developer                  Project Type  \
# 0       Tradewater, LLC    Ozone Depleting Substances
# 1       Tradewater, LLC    Ozone Depleting Substances
# 2  Therm Solutions Inc.  Industrial Process Emissions
# 3  Therm Solutions Inc.  Industrial Process Emissions
# 4    Keyrock Energy LLC             Coal Mine Methane
#
#                         Project Methodology/Protocol  \
# 0  Destruction of Ozone Depleting Substances (ODS...
# 1  ARB Compliance Offset Protocol: Destruction of...
# 2                     Advanced Refrigeration Systems
# 3                     Advanced Refrigeration Systems
# 4  ARB Compliance Offset Protocol: Mine Methane C...
#
#   Methodology/Protocol Version Verified Removal ARB Eligible CORSIA Qualified  \
# 0                  Version 1.0              NaN           No               No
# 1            November 14, 2014              NaN          Yes               No
# 2                  Version 2.1              NaN           No               No
# 3                  Version 2.1              NaN           No               No
# 4               April 25, 2014              NaN          Yes               No
#
#    ...  Credits Issued to Project  Credits Issued to Buffer Pool  \
# 0  ...                     113973                              0
# 1  ...                     132823                              0
# 2  ...                       6805                              0
# 3  ...                      19002                              0
# 4  ...                      41618                              0
#
#                                Project Site Location  Project Site State  \
# 0  965 Moo 2 Soi 3B Bangpoo Industrial Estate, Su...        Samut Prakan
# 1                                      Bowling Green                OHIO
# 2                 18 Winslow Gate Road, Poughkeepsie            NEW YORK
# 3          543 12th St Dr NW, Hickory, NC 28601, USA      NORTH CAROLINA
# 4                                       Crab Orchard       WEST VIRGINIA
#
#   Project Site Country                    Sustainable Development Goal(s)  \
# 0                   TH  09: Industry, Innovation and Infrastructure;12...
# 1                   US  09: Industry, Innovation and Infrastructure;12...
# 2                   US  09: Industry, Innovation and Infrastructure;11...
# 3                   US  09: Industry, Innovation and Infrastructure;11...
# 4                   US  09: Industry, Innovation and Infrastructure;13...
#
#                  Project VVB Project Website Documents Unnamed: 21
# 0                GHD Limited             NaN      View         NaN
# 1                  SES, Inc.             NaN      View         NaN
# 2    First Environment, Inc.             NaN      View         NaN
# 3    Ruby Canyon Environment             NaN      View         NaN
# 4  Dillon Consulting Limited             NaN      View         NaN
#
# [5 rows x 22 columns]

# %%
acr_data = acr_data[['Date Issued', 'Credits Issued to Project']]
acr_data = acr_data.rename(columns={'Date Issued': 'Issuance Date', 'Credits Issued to Project': 'Quantity'})

# %%
car_data = pd.read_csv('car.csv',  encoding='cp1252')
car_data
# Out:
#     Project ID    ARB ID Cooperative/ Aggregate ID  \
# 0      CAR1460       NaN                  CARC1397
# 1      CAR1458  CAOD6458                       NaN
# 2      CAR1560  CAOD6560                       NaN
# 3      CAR1662  CAOD6662                       NaN
# 4      CAR1481  CAOD6481                       NaN
# ..         ...       ...                       ...
# 816    CAR1352       NaN                  CARC1519
# 817    CAR1232  CALS5332                       NaN
# 818     CAR777       NaN                       NaN
# 819     CAR993  CAFR5011                       NaN
# 820     CAR801       NaN                       NaN
#
#                                      Project Developer  \
# 0                                    The Climate Trust
# 1                        Reclamation Technologies Inc.
# 2                        Reclamation Technologies Inc.
# 3                        Reclamation Technologies Inc.
# 4                        Reclamation Technologies Inc.
# ..                                                 ...
# 816  ASOCIACIÓN DE SILVICULTORES DE LA REGIÓN FORES...
# 817               Native, a Public Benefit Corporation
# 818                                        Yurok Tribe
# 819                                        Yurok Tribe
# 820                                        ClimeCo LLC
#
#                             Project Owner  \
# 0                  The Nature Conservancy
# 1           Reclamation Technologies Inc.
# 2           Reclamation Technologies Inc.
# 3           Reclamation Technologies Inc.
# 4           Reclamation Technologies Inc.
# ..                                    ...
# 816                    Ejido Xahuayalulco
# 817  Native, a Public Benefit Corporation
# 818                           Yurok Tribe
# 819                           Yurok Tribe
# 820                           ClimeCo LLC
#
#                                           Project Name  \
# 0                                             54 Ranch
# 1                                         A-Gas 1-2021
# 2                                         A-Gas 1-2022
# 3                                         A-Gas 1-2023
# 4                                         A-Gas 2-2021
# ..                                                 ...
# 816                       Xahuayalulco - ASRTulancingo
# 817                                       Yippee Farms
# 818             Yurok Tribe Sustainable Forest Project
# 819  Yurok Tribe/Forest Carbon Partners CKGG Improv...
# 820                       Z-Best Food Waste Composting
#
#                        Offset Project Operator Authorized Project Designee  \
# 0                                          NaN                         NaN
# 1    Reclamation Technologies, Inc., dba A-Gas                        None
# 2                                 A-Gas US Inc                        None
# 3                                 A-Gas US Inc                        None
# 4    Reclamation Technologies, Inc., dba A-Gas                        None
# ..                                         ...                         ...
# 816                                        NaN                         NaN
# 817                               Arlin Benner          NativeEnergy, Inc.
# 818                                Yurok Tribe                         NaN
# 819                                Yurok Tribe                        None
# 820                                        NaN                         NaN
#
#                          Verification Body  \
# 0                                      NaN
# 1                                      NaN
# 2                       GHD Services, Inc.
# 3          Ruby Canyon Environmental, Inc.
# 4                       GHD Services, Inc.
# ..                                     ...
# 816                                    NaN
# 817  First Environment of California, Inc.
# 818                                    NaN
# 819                                    NaN
# 820                                    NaN
#
#                                           Project Type  ...  \
# 0                         Avoided Grassland Conversion  ...
# 1    Ozone Depleting Substances - U.S. - ARB Compli...  ...
# 2    Ozone Depleting Substances - U.S. - ARB Compli...  ...
# 3    Ozone Depleting Substances - U.S. - ARB Compli...  ...
# 4    Ozone Depleting Substances - U.S. - ARB Compli...  ...
# ..                                                 ...  ...
# 816                                      Forestry - MX  ...
# 817                         Livestock - ARB Compliance  ...
# 818                         Improved Forest Management  ...
# 819        Improved Forest Management - ARB Compliance  ...
# 820                           Organic Waste Composting  ...
#
#     Project Site Country Additional Certification(s) SDG Impact  \
# 0                     US                         NaN        NaN
# 1                     US                         NaN        NaN
# 2                     US                         NaN        NaN
# 3                     US                         NaN        NaN
# 4                     US                         NaN        NaN
# ..                   ...                         ...        ...
# 816                   MX                         NaN        NaN
# 817                   US                         NaN        NaN
# 818                   US                         NaN        NaN
# 819                   US                         NaN        NaN
# 820                   US                         NaN        NaN
#
#                                          Project Notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 816                                                NaN
# 817                                                NaN
# 818  Re-listed as CAR1070 to transition to the comp...
# 819                                                NaN
# 820                                                NaN
#
#     Total Number of Offset Credits Registered   Project Listed Date  \
# 0                                          NaN           01/05/2021
# 1                                      84267.0           11/20/2020
# 2                                      59147.0           02/17/2022
# 3                                          NaN           10/11/2022
# 4                                      56964.0           03/16/2021
# ..                                         ...                  ...
# 816                                     6776.0           06/24/2019
# 817                                    31532.0           04/19/2016
# 818                                  1336270.0           10/05/2011
# 819                                  1142620.0           06/28/2013
# 820                                    49448.0           01/25/2011
#
#     Project Registered Date Documents  Data               Project Website
# 0                       NaN      View  View                           NaN
# 1                01/28/2021      View  View          www.agasamericas.com
# 2                05/27/2022      View  View          www.agasamericas.com
# 3                       NaN      View  View          www.agasamericas.com
# 4                06/09/2021      View  View          www.agasamericas.com
# ..                      ...       ...   ...                           ...
# 816              02/25/2021      View  View                           NaN
# 817              03/07/2017      View  View                           NaN
# 818              08/14/2013      View  View            www.yuroktribe.org
# 819              02/11/2014      View  View  www.forestcarbonpartners.com
# 820              09/20/2013      View  View       www.zankerrecycling.com
#
# [821 rows x 24 columns]

# %%
car_data.columns
# Out:
# Index(['Project ID', 'ARB ID', 'Cooperative/ Aggregate ID',
#        'Project Developer', 'Project Owner', 'Project Name',
#        'Offset Project Operator', 'Authorized Project Designee',
#        'Verification Body', 'Project Type', 'Status', 'ARB Project Status',
#        'Project Site Location', 'Project Site State', 'Project Site Country',
#        'Additional Certification(s)', 'SDG Impact', 'Project Notes',
#        'Total Number of Offset Credits Registered ', 'Project Listed Date',
#        'Project Registered Date', 'Documents', 'Data', 'Project Website'],
#       dtype='object')

# %%
car_data = car_data[['Project Listed Date', 'Total Number of Offset Credits Registered ']]
car_data = car_data.rename(columns={'Project Listed Date': 'Issuance Date', 'Total Number of Offset Credits Registered ': 'Quantity'})
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Issuance Date  820 non-null    object
#  1   Quantity       626 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.0+ KB

# %%
car_data.isna().sum()
car_data = car_data.dropna()
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 626 entries, 1 to 820
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Issuance Date  626 non-null    object
#  1   Quantity       626 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.7+ KB

# %%
gcc = pd.DataFrame({'Issuance Date': ['10-01-2018', '07-05-2019', '10-01-2019', '07-05-2019', '07-05-2019', '01-01-2021'], 'Quantity': [133667, 74712, 11476, 155309, 168225, 407455]})
gcc
# Out:
#   Issuance Date  Quantity
# 0    10-01-2018    133667
# 1    07-05-2019     74712
# 2    10-01-2019     11476
# 3    07-05-2019    155309
# 4    07-05-2019    168225
# 5    01-01-2021    407455

# %%
cf2 = pd.read_csv('cf2.csv', encoding='cp1252')
cf2 = cf2[['Project Registered Date', 'Total Number of Mitigation Units Registered ']]
cf2 = cf2.dropna()
cf2 = cf2.rename(columns={'Project Registered Date': 'Issuance Date', 'Total Number of Mitigation Units Registered ': 'Quantity'})
cf2
# Out:
#    Issuance Date  Quantity
# 3     05/02/2019    6507.0
# 8     06/27/2019  140901.0
# 9     08/05/2019  140647.0
# 10    02/10/2020  211663.0
# 12    12/16/2019    1073.0
# 13    12/11/2020    1202.0
# 14    01/21/2022     914.0
# 15    12/16/2019     278.0

# %%
vcs_data = pd.read_csv('check.csv', encoding = 'cp1252', low_memory = False)
vcs_data =vcs_data[['Crediting Period Start', 'Estimated Annual Emission Reductions']]
vcs_data = vcs_data.dropna()
vcs_data = vcs_data.reset_index()
vcs_data = vcs_data.drop('index', axis = 1)
vcs_data = vcs_data.rename(columns={'Crediting Period Start': 'Issuance Date', 'Estimated Annual Emission Reductions': 'Quantity'})
vcs_data
# Out:
#      Issuance Date   Quantity
# 0       2020-04-01    13331.0
# 1       2016-01-01   608686.0
# 2       2008-04-01     9900.0
# 3       2017-06-01    67000.0
# 4       2019-06-05  1293422.0
# ...            ...        ...
# 2523    2021-04-01    23820.0
# 2524    2021-08-21    17243.0
# 2525    2022-10-10    56149.0
# 2526    2020-03-02    59906.0
# 2527    2020-02-28    59943.0
#
# [2528 rows x 2 columns]

# %%
vcs_data = vcs_data[vcs_data['Quantity'] < 100000000]

# %%
car2_data = pd.read_csv('check2.csv', encoding = 'cp1252', low_memory = False)
car2_data =car2_data[['Date \nIssued', 'Total Offset Credits Issued']]
car2_data = car2_data.rename(columns={'Date \nIssued': 'Issuance Date', 'Total Offset Credits Issued': 'Quantity'})
car2_data = car2_data.dropna()
car2_data
# Out:
#      Issuance Date  Quantity
# 0       2014-02-07  126155.0
# 1       2015-04-09    1282.0
# 2       2015-04-09    7810.0
# 3       2015-01-31    5829.0
# 4       2017-01-28    2269.0
# ...            ...       ...
# 3278    2018-08-13    1712.0
# 3279    2019-11-22    5971.0
# 3280    2019-11-22    2436.0
# 3281    2021-02-05    4751.0
# 3282    2021-02-05    2138.0
#
# [3283 rows x 2 columns]

# %%
important_data = pd.concat([important_data, acr_data, gcc, cf2,  car2_data, car_data], axis = 0)

# %%
#important_data = important_data[important_data['Quantity'] < 100000]

# %%
important_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107832 entries, 0 to 820
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Issuance Date  107832 non-null  object
#  1   Quantity       107832 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ MB

# %%
important_data['Issuance Date'] = pd.to_datetime(important_data['Issuance Date'])

# %%
important_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107832 entries, 0 to 820
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Issuance Date  107832 non-null  datetime64[ns]
#  1   Quantity       107832 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.5 MB

# %%
#important_data = important_data[important_data['Issuance Date'].dt.year>=2012]

# %%
important_data = important_data[important_data['Issuance Date'].dt.year<=2020]

# %%
important_data = pd.read_csv('final_data.csv', parse_dates = ['Issuance Date'], index_col = ['Issuance Date'])

# %%
#important_data.set_index('Issuance Date', inplace=True)

# aggregate by week
#weekly = important_data.resample('M').sum()

# reset index and convert date back to string format
#weekly.reset_index(inplace=True)
#weekly

# %%
#weekly.to_csv('monthly.csv')

# %%
weekly = important_data
weekly.describe()
# Out:
#            Quantity
# count  2.100000e+02
# mean   2.772686e+06
# std    1.854637e+06
# min    0.000000e+00
# 25%    1.413200e+06
# 50%    2.709716e+06
# 75%    3.784911e+06
# max    7.634959e+06

# %%
import matplotlib.pyplot as plt
plt.plot(weekly['Quantity'], linewidth = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

rolling_mean = weekly['Quantity'].rolling(window=3).mean()
rolling_std = weekly['Quantity'].rolling(window=3).std()

plt.plot(weekly['Quantity'], color='blue', label='Original')
plt.plot(rolling_mean, color='red', label='Rolling Mean')
plt.plot(rolling_std, color='green', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean and Standard Deviation')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
adftest = adfuller(weekly)
adftest[1]
# Out:
# 0.18203066400320272

# %%
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(weekly, model = 'additive')
fig = decomposition.plot()
plt.show()

# %%
weekly = weekly.diff(periods = 1)
weekly = weekly.dropna()
weekly.plot()
# Out:
# <AxesSubplot: xlabel='Issuance Date'>

# %%
#from statsmodels.tsa.stattools import adfuller
#adftest = adfuller(weekly)
#adftest[1]

# %%
#actual_data = weekly['Quantity']

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(weekly[['Quantity']])
weekly['Quantity'] = scaler.transform(weekly[['Quantity']])
weekly
# Out:
#                Quantity
# Issuance Date
# 2005-08-31     0.356581
# 2005-09-30     0.524587
# 2005-10-31     0.672943
# 2005-11-30     0.376231
# 2005-12-31     0.576763
# ...                 ...
# 2022-08-31     0.413412
# 2022-09-30     0.584188
# 2022-10-31     0.277079
# 2022-11-30     0.747045
# 2022-12-31     0.635072
#
# [209 rows x 1 columns]

# %%
plt.plot( weekly['Quantity'], linewidth = 0.5)
plt.show()

# %%
weekly
# Out:
#                Quantity
# Issuance Date
# 2005-08-31     0.356581
# 2005-09-30     0.524587
# 2005-10-31     0.672943
# 2005-11-30     0.376231
# 2005-12-31     0.576763
# ...                 ...
# 2022-08-31     0.413412
# 2022-09-30     0.584188
# 2022-10-31     0.277079
# 2022-11-30     0.747045
# 2022-12-31     0.635072
#
# [209 rows x 1 columns]

# %%
weekly['Quantity'].value_counts()
# Out:
# 0.524587    5
# 0.668460    1
# 0.645011    1
# 0.233715    1
# 0.614550    1
#            ..
# 0.595057    1
# 0.408086    1
# 0.678275    1
# 0.385651    1
# 0.635072    1
# Name: Quantity, Length: 205, dtype: int64

# %%
#weekly['Issuance Date'] = pd.to_datetime(weekly['Issuance Date'])
#weekly['Issuance Date'] = weekly['Issuance Date'].apply(lambda x: x.timestamp())

# %%
weekly = weekly[['Quantity']]

# %%
train_size = int(len(weekly) * 0.8)
val_size = int(len(weekly) * 0.1)
train_data = weekly.iloc[:train_size]
val_data = weekly.iloc[train_size: train_size + val_size]
test_data = weekly.iloc[train_size + val_size:]

# %%
import numpy as np
#train_data = scaler.fit_transform(train_data)
#val_data = scaler.transform(val_data)
#test_data = scaler.transform(test_data)
train_data = np.array(train_data)
val_data = np.array(val_data)
test_data = np.array(test_data)

# %%
import numpy as np
def generate_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length):
        try:
            X.append(data[i:i+seq_length])
            y.append(data[i+seq_length])
        except KeyError:
            break
    return np.array(X), np.array(y)

# %%
seq_length = 2
X_train, y_train = generate_sequences(train_data, seq_length)
X_val, y_val = generate_sequences(val_data, seq_length)
X_test, y_test = generate_sequences(test_data, seq_length)

# %%
X_test, y_test = generate_sequences(test_data, seq_length)

# %%
X_val.shape
# Out:
# (18, 2, 1)

# %%
X_test.shape
# Out:
# (20, 2, 1)

# %%
X_train.shape
# Out:
# (165, 2, 1)

# %%
X_train
# Out:
# array([[[0.35658087],
#         [0.52458724]],
#
#        [[0.52458724],
#         [0.67294332]],
#
#        [[0.67294332],
#         [0.37623117]],
#
#        [[0.37623117],
#         [0.57676278]],
#
#        [[0.57676278],
#         [0.49001973]],
#
#        [[0.49001973],
#         [0.50697922]],
#
#        [[0.50697922],
#         [0.89255956]],
#
#        [[0.89255956],
#         [0.15661493]],
#
#        [[0.15661493],
#         [0.52458724]],
#
#        [[0.52458724],
#         [0.52458724]],
#
#        [[0.52458724],
#         [0.52488364]],
#
#        [[0.52488364],
#         [1.        ]],
#
#        [[1.        ],
#         [0.04887809]],
#
#        [[0.04887809],
#         [0.52458724]],
#
#        [[0.52458724],
#         [0.52458724]],
#
#        [[0.52458724],
#         [0.52493187]],
#
#        [[0.52493187],
#         [0.72371455]],
#
#        [[0.72371455],
#         [0.32511531]],
#
#        [[0.32511531],
#         [0.61066605]],
#
#        [[0.61066605],
#         [0.44060684]],
#
#        [[0.44060684],
#         [0.52264978]],
#
#        [[0.52264978],
#         [0.54731027]],
#
#        [[0.54731027],
#         [0.50170328]],
#
#        [[0.50170328],
#         [0.5749539 ]],
#
#        [[0.5749539 ],
#         [0.51488438]],
#
#        [[0.51488438],
#         [0.49536719]],
#
#        [[0.49536719],
#         [0.51968876]],
#
#        [[0.51968876],
#         [0.59605954]],
#
#        [[0.59605954],
#         [0.44656969]],
#
#        [[0.44656969],
#         [0.56183674]],
#
#        [[0.56183674],
#         [0.67475361]],
#
#        [[0.67475361],
#         [0.3629318 ]],
#
#        [[0.3629318 ],
#         [0.52678335]],
#
#        [[0.52678335],
#         [0.49663072]],
#
#        [[0.49663072],
#         [0.56566601]],
#
#        [[0.56566601],
#         [0.56903599]],
#
#        [[0.56903599],
#         [0.46008674]],
#
#        [[0.46008674],
#         [0.70595372]],
#
#        [[0.70595372],
#         [0.44955807]],
#
#        [[0.44955807],
#         [0.70981497]],
#
#        [[0.70981497],
#         [0.34534043]],
#
#        [[0.34534043],
#         [0.43481439]],
#
#        [[0.43481439],
#         [0.72544543]],
#
#        [[0.72544543],
#         [0.36145114]],
#
#        [[0.36145114],
#         [0.86097652]],
#
#        [[0.86097652],
#         [0.3559722 ]],
#
#        [[0.3559722 ],
#         [0.56833642]],
#
#        [[0.56833642],
#         [0.33219622]],
#
#        [[0.33219622],
#         [0.86166538]],
#
#        [[0.86166538],
#         [0.21538098]],
#
#        [[0.21538098],
#         [0.60971432]],
#
#        [[0.60971432],
#         [0.48016851]],
#
#        [[0.48016851],
#         [0.43018846]],
#
#        [[0.43018846],
#         [0.54999561]],
#
#        [[0.54999561],
#         [0.66725983]],
#
#        [[0.66725983],
#         [0.53403154]],
#
#        [[0.53403154],
#         [0.50484996]],
#
#        [[0.50484996],
#         [0.39960263]],
#
#        [[0.39960263],
#         [0.64957186]],
#
#        [[0.64957186],
#         [0.71821458]],
#
#        [[0.71821458],
#         [0.1802055 ]],
#
#        [[0.1802055 ],
#         [0.63958439]],
#
#        [[0.63958439],
#         [0.43413998]],
#
#        [[0.43413998],
#         [0.71642541]],
#
#        [[0.71642541],
#         [0.35107121]],
#
#        [[0.35107121],
#         [0.58993638]],
#
#        [[0.58993638],
#         [0.4714091 ]],
#
#        [[0.4714091 ],
#         [0.50469987]],
#
#        [[0.50469987],
#         [0.55395917]],
#
#        [[0.55395917],
#         [0.71101245]],
#
#        [[0.71101245],
#         [0.28688196]],
#
#        [[0.28688196],
#         [0.71236297]],
#
#        [[0.71236297],
#         [0.38270904]],
#
#        [[0.38270904],
#         [0.59505677]],
#
#        [[0.59505677],
#         [0.40808606]],
#
#        [[0.40808606],
#         [0.67827539]],
#
#        [[0.67827539],
#         [0.38565108]],
#
#        [[0.38565108],
#         [0.62743052]],
#
#        [[0.62743052],
#         [0.50087388]],
#
#        [[0.50087388],
#         [0.44075051]],
#
#        [[0.44075051],
#         [0.52788828]],
#
#        [[0.52788828],
#         [0.58318016]],
#
#        [[0.58318016],
#         [0.53359874]],
#
#        [[0.53359874],
#         [0.93523624]],
#
#        [[0.93523624],
#         [0.        ]],
#
#        [[0.        ],
#         [0.58732998]],
#
#        [[0.58732998],
#         [0.48296039]],
#
#        [[0.48296039],
#         [0.56949052]],
#
#        [[0.56949052],
#         [0.47404253]],
#
#        [[0.47404253],
#         [0.60327342]],
#
#        [[0.60327342],
#         [0.49864869]],
#
#        [[0.49864869],
#         [0.53654953]],
#
#        [[0.53654953],
#         [0.633588  ]],
#
#        [[0.633588  ],
#         [0.52929673]],
#
#        [[0.52929673],
#         [0.3936555 ]],
#
#        [[0.3936555 ],
#         [0.67946075]],
#
#        [[0.67946075],
#         [0.37514265]],
#
#        [[0.37514265],
#         [0.67598822]],
#
#        [[0.67598822],
#         [0.46026011]],
#
#        [[0.46026011],
#         [0.51573403]],
#
#        [[0.51573403],
#         [0.56910228]],
#
#        [[0.56910228],
#         [0.66086403]],
#
#        [[0.66086403],
#         [0.24874226]],
#
#        [[0.24874226],
#         [0.74691938]],
#
#        [[0.74691938],
#         [0.54365061]],
#
#        [[0.54365061],
#         [0.28594579]],
#
#        [[0.28594579],
#         [0.78209392]],
#
#        [[0.78209392],
#         [0.42601479]],
#
#        [[0.42601479],
#         [0.52135178]],
#
#        [[0.52135178],
#         [0.59058342]],
#
#        [[0.59058342],
#         [0.29526205]],
#
#        [[0.29526205],
#         [0.65315404]],
#
#        [[0.65315404],
#         [0.47658975]],
#
#        [[0.47658975],
#         [0.56796367]],
#
#        [[0.56796367],
#         [0.4855695 ]],
#
#        [[0.4855695 ],
#         [0.5544559 ]],
#
#        [[0.5544559 ],
#         [0.89812229]],
#
#        [[0.89812229],
#         [0.17633777]],
#
#        [[0.17633777],
#         [0.76463168]],
#
#        [[0.76463168],
#         [0.15538501]],
#
#        [[0.15538501],
#         [0.61040444]],
#
#        [[0.61040444],
#         [0.55179137]],
#
#        [[0.55179137],
#         [0.72015962]],
#
#        [[0.72015962],
#         [0.27306241]],
#
#        [[0.27306241],
#         [0.41312532]],
#
#        [[0.41312532],
#         [0.65072923]],
#
#        [[0.65072923],
#         [0.49500451]],
#
#        [[0.49500451],
#         [0.46873728]],
#
#        [[0.46873728],
#         [0.64495764]],
#
#        [[0.64495764],
#         [0.63059892]],
#
#        [[0.63059892],
#         [0.34705059]],
#
#        [[0.34705059],
#         [0.83043557]],
#
#        [[0.83043557],
#         [0.37708433]],
#
#        [[0.37708433],
#         [0.64501064]],
#
#        [[0.64501064],
#         [0.23371522]],
#
#        [[0.23371522],
#         [0.61455014]],
#
#        [[0.61455014],
#         [0.44181009]],
#
#        [[0.44181009],
#         [0.5222223 ]],
#
#        [[0.5222223 ],
#         [0.654377  ]],
#
#        [[0.654377  ],
#         [0.48313907]],
#
#        [[0.48313907],
#         [0.85529139]],
#
#        [[0.85529139],
#         [0.19068362]],
#
#        [[0.19068362],
#         [0.38071451]],
#
#        [[0.38071451],
#         [0.66845998]],
#
#        [[0.66845998],
#         [0.81432711]],
#
#        [[0.81432711],
#         [0.34292789]],
#
#        [[0.34292789],
#         [0.42755831]],
#
#        [[0.42755831],
#         [0.51353567]],
#
#        [[0.51353567],
#         [0.82489815]],
#
#        [[0.82489815],
#         [0.30696881]],
#
#        [[0.30696881],
#         [0.46170475]],
#
#        [[0.46170475],
#         [0.53930709]],
#
#        [[0.53930709],
#         [0.70171408]],
#
#        [[0.70171408],
#         [0.51933796]],
#
#        [[0.51933796],
#         [0.36594715]],
#
#        [[0.36594715],
#         [0.53843165]],
#
#        [[0.53843165],
#         [0.62246224]],
#
#        [[0.62246224],
#         [0.33482575]],
#
#        [[0.33482575],
#         [0.71257683]],
#
#        [[0.71257683],
#         [0.37946319]],
#
#        [[0.37946319],
#         [0.47595139]],
#
#        [[0.47595139],
#         [0.45154619]],
#
#        [[0.45154619],
#         [0.55550245]],
#
#        [[0.55550245],
#         [0.82079805]],
#
#        [[0.82079805],
#         [0.58779217]]])

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization, Bidirectional, Flatten
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

# Define the LSTM model
model = Sequential()
model.add(LSTM(units=32, input_shape=( 2,1), return_sequences = True))
model.add(Dropout(0.5))
#model.add(LSTM(units=32,  stateful = True))
model.add(Dense(units=1))

# %%
import tensorflow
model.compile(optimizer='rmsprop', loss='mean_squared_error', metrics = ['RootMeanSquaredError'])
stop = EarlyStopping(monitor='val_loss', mode = 'min', patience = 50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
model.fit(X_train, y_train, epochs=300, verbose=1, batch_size = 1, shuffle = False, validation_data = (X_val, y_val), callbacks = [stop, mc])
model.summary()
# Out:
# Epoch 1/300
# 165/165 [==============================] - 3s 4ms/step - loss: 0.0948 - root_mean_squared_error: 0.3079 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2615
#
# Epoch 00001: val_loss improved from inf to 0.06836, saving model to best_model.h5
# Epoch 2/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0476 - root_mean_squared_error: 0.2182 - val_loss: 0.0601 - val_root_mean_squared_error: 0.2451
#
# Epoch 00002: val_loss improved from 0.06836 to 0.06006, saving model to best_model.h5
# Epoch 3/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0419 - root_mean_squared_error: 0.2048 - val_loss: 0.0563 - val_root_mean_squared_error: 0.2373
#
# Epoch 00003: val_loss improved from 0.06006 to 0.05632, saving model to best_model.h5
# Epoch 4/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0378 - root_mean_squared_error: 0.1945 - val_loss: 0.0544 - val_root_mean_squared_error: 0.2332
#
# Epoch 00004: val_loss improved from 0.05632 to 0.05439, saving model to best_model.h5
# Epoch 5/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0354 - root_mean_squared_error: 0.1880 - val_loss: 0.0533 - val_root_mean_squared_error: 0.2308
#
# Epoch 00005: val_loss improved from 0.05439 to 0.05326, saving model to best_model.h5
# Epoch 6/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0355 - root_mean_squared_error: 0.1883 - val_loss: 0.0526 - val_root_mean_squared_error: 0.2293
#
# Epoch 00006: val_loss improved from 0.05326 to 0.05256, saving model to best_model.h5
# Epoch 7/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0323 - root_mean_squared_error: 0.1797 - val_loss: 0.0517 - val_root_mean_squared_error: 0.2273
#
# Epoch 00007: val_loss improved from 0.05256 to 0.05169, saving model to best_model.h5
# Epoch 8/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0341 - root_mean_squared_error: 0.1847 - val_loss: 0.0511 - val_root_mean_squared_error: 0.2261
#
# Epoch 00008: val_loss improved from 0.05169 to 0.05111, saving model to best_model.h5
# Epoch 9/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0337 - root_mean_squared_error: 0.1835 - val_loss: 0.0504 - val_root_mean_squared_error: 0.2245
#
# Epoch 00009: val_loss improved from 0.05111 to 0.05040, saving model to best_model.h5
# Epoch 10/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0335 - root_mean_squared_error: 0.1831 - val_loss: 0.0498 - val_root_mean_squared_error: 0.2231
#
# Epoch 00010: val_loss improved from 0.05040 to 0.04978, saving model to best_model.h5
# Epoch 11/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0328 - root_mean_squared_error: 0.1811 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2220
#
# Epoch 00011: val_loss improved from 0.04978 to 0.04929, saving model to best_model.h5
# Epoch 12/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0313 - root_mean_squared_error: 0.1768 - val_loss: 0.0488 - val_root_mean_squared_error: 0.2210
#
# Epoch 00012: val_loss improved from 0.04929 to 0.04882, saving model to best_model.h5
# Epoch 13/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0300 - root_mean_squared_error: 0.1733 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2199
#
# Epoch 00013: val_loss improved from 0.04882 to 0.04836, saving model to best_model.h5
# Epoch 14/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0304 - root_mean_squared_error: 0.1744 - val_loss: 0.0480 - val_root_mean_squared_error: 0.2191
#
# Epoch 00014: val_loss improved from 0.04836 to 0.04801, saving model to best_model.h5
# Epoch 15/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0298 - root_mean_squared_error: 0.1726 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2182
#
# Epoch 00015: val_loss improved from 0.04801 to 0.04759, saving model to best_model.h5
# Epoch 16/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0309 - root_mean_squared_error: 0.1756 - val_loss: 0.0473 - val_root_mean_squared_error: 0.2175
#
# Epoch 00016: val_loss improved from 0.04759 to 0.04731, saving model to best_model.h5
# Epoch 17/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0309 - root_mean_squared_error: 0.1758 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2170
#
# Epoch 00017: val_loss improved from 0.04731 to 0.04707, saving model to best_model.h5
# Epoch 18/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0304 - root_mean_squared_error: 0.1744 - val_loss: 0.0469 - val_root_mean_squared_error: 0.2166
#
# Epoch 00018: val_loss improved from 0.04707 to 0.04692, saving model to best_model.h5
# Epoch 19/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0295 - root_mean_squared_error: 0.1719 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2162
#
# Epoch 00019: val_loss improved from 0.04692 to 0.04676, saving model to best_model.h5
# Epoch 20/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0298 - root_mean_squared_error: 0.1726 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2154
#
# Epoch 00020: val_loss improved from 0.04676 to 0.04638, saving model to best_model.h5
# Epoch 21/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0300 - root_mean_squared_error: 0.1732 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2150
#
# Epoch 00021: val_loss improved from 0.04638 to 0.04622, saving model to best_model.h5
# Epoch 22/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2141
#
# Epoch 00022: val_loss improved from 0.04622 to 0.04584, saving model to best_model.h5
# Epoch 23/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0288 - root_mean_squared_error: 0.1696 - val_loss: 0.0457 - val_root_mean_squared_error: 0.2137
#
# Epoch 00023: val_loss improved from 0.04584 to 0.04566, saving model to best_model.h5
# Epoch 24/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0293 - root_mean_squared_error: 0.1710 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2132
#
# Epoch 00024: val_loss improved from 0.04566 to 0.04547, saving model to best_model.h5
# Epoch 25/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0306 - root_mean_squared_error: 0.1748 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2131
#
# Epoch 00025: val_loss improved from 0.04547 to 0.04542, saving model to best_model.h5
# Epoch 26/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0287 - root_mean_squared_error: 0.1694 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2130
#
# Epoch 00026: val_loss improved from 0.04542 to 0.04536, saving model to best_model.h5
# Epoch 27/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0294 - root_mean_squared_error: 0.1715 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2130
#
# Epoch 00027: val_loss improved from 0.04536 to 0.04535, saving model to best_model.h5
# Epoch 28/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0286 - root_mean_squared_error: 0.1692 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2128
#
# Epoch 00028: val_loss improved from 0.04535 to 0.04526, saving model to best_model.h5
# Epoch 29/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
#
# Epoch 00029: val_loss improved from 0.04526 to 0.04512, saving model to best_model.h5
# Epoch 30/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2122
#
# Epoch 00030: val_loss improved from 0.04512 to 0.04504, saving model to best_model.h5
# Epoch 31/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0282 - root_mean_squared_error: 0.1681 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2121
#
# Epoch 00031: val_loss improved from 0.04504 to 0.04499, saving model to best_model.h5
# Epoch 32/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0276 - root_mean_squared_error: 0.1660 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2121
# Epoch 00032: val_loss improved from 0.04499 to 0.04498, saving model to best_model.h5
# Epoch 33/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0270 - root_mean_squared_error: 0.1645 - val_loss: 0.0449 - val_root_mean_squared_error: 0.2119
#
# Epoch 00033: val_loss improved from 0.04498 to 0.04490, saving model to best_model.h5
# Epoch 34/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2115
#
# Epoch 00034: val_loss improved from 0.04490 to 0.04472, saving model to best_model.h5
# Epoch 35/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2115
#
# Epoch 00035: val_loss did not improve from 0.04472
# Epoch 36/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0300 - root_mean_squared_error: 0.1733 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2121
#
# Epoch 00036: val_loss did not improve from 0.04472
# Epoch 37/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2115
#
# Epoch 00037: val_loss did not improve from 0.04472
# Epoch 38/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0291 - root_mean_squared_error: 0.1705 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2114
#
# Epoch 00038: val_loss improved from 0.04472 to 0.04469, saving model to best_model.h5
# Epoch 39/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0289 - root_mean_squared_error: 0.1701 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2115
#
# Epoch 00039: val_loss did not improve from 0.04469
# Epoch 40/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0283 - root_mean_squared_error: 0.1681 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2110
#
# Epoch 00040: val_loss improved from 0.04469 to 0.04452, saving model to best_model.h5
# Epoch 41/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0273 - root_mean_squared_error: 0.1653 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2108
#
# Epoch 00041: val_loss improved from 0.04452 to 0.04443, saving model to best_model.h5
# Epoch 42/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2109
#
# Epoch 00042: val_loss did not improve from 0.04443
# Epoch 43/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0281 - root_mean_squared_error: 0.1675 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2112
#
# Epoch 00043: val_loss did not improve from 0.04443
# Epoch 44/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0278 - root_mean_squared_error: 0.1666 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2114
#
# Epoch 00044: val_loss did not improve from 0.04443
# Epoch 45/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0280 - root_mean_squared_error: 0.1672 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2117
#
# Epoch 00045: val_loss did not improve from 0.04443
# Epoch 46/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0274 - root_mean_squared_error: 0.1654 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2110
#
# Epoch 00046: val_loss did not improve from 0.04443
# Epoch 47/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2108
#
# Epoch 00047: val_loss improved from 0.04443 to 0.04442, saving model to best_model.h5
# Epoch 48/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0273 - root_mean_squared_error: 0.1653 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2107
#
# Epoch 00048: val_loss improved from 0.04442 to 0.04439, saving model to best_model.h5
# Epoch 49/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0278 - root_mean_squared_error: 0.1667 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2107
#
# Epoch 00049: val_loss did not improve from 0.04439
# Epoch 50/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0275 - root_mean_squared_error: 0.1657 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2107
#
# Epoch 00050: val_loss did not improve from 0.04439
# Epoch 51/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0277 - root_mean_squared_error: 0.1664 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2105
#
# Epoch 00051: val_loss improved from 0.04439 to 0.04431, saving model to best_model.h5
# Epoch 52/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2105
#
# Epoch 00052: val_loss improved from 0.04431 to 0.04430, saving model to best_model.h5
# Epoch 53/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0278 - root_mean_squared_error: 0.1666 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2104
#
# Epoch 00053: val_loss improved from 0.04430 to 0.04427, saving model to best_model.h5
# Epoch 54/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0264 - root_mean_squared_error: 0.1624 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2096
#
# Epoch 00054: val_loss improved from 0.04427 to 0.04395, saving model to best_model.h5
# Epoch 55/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0273 - root_mean_squared_error: 0.1653 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2096
#
# Epoch 00055: val_loss improved from 0.04395 to 0.04394, saving model to best_model.h5
# Epoch 56/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647 - val_loss: 0.0440 - val_root_mean_squared_error: 0.2098
#
# Epoch 00056: val_loss did not improve from 0.04394
# Epoch 57/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0271 - root_mean_squared_error: 0.1646 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2094
#
# Epoch 00057: val_loss improved from 0.04394 to 0.04385, saving model to best_model.h5
# Epoch 58/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0440 - val_root_mean_squared_error: 0.2097
#
# Epoch 00058: val_loss did not improve from 0.04385
# Epoch 59/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2090
#
# Epoch 00059: val_loss improved from 0.04385 to 0.04367, saving model to best_model.h5
# Epoch 60/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0271 - root_mean_squared_error: 0.1645 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
#
# Epoch 00060: val_loss did not improve from 0.04367
# Epoch 61/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
#
# Epoch 00061: val_loss did not improve from 0.04367
# Epoch 62/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0270 - root_mean_squared_error: 0.1642 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
#
# Epoch 00062: val_loss did not improve from 0.04367
# Epoch 63/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2094
#
# Epoch 00063: val_loss did not improve from 0.04367
# Epoch 64/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2090
#
# Epoch 00064: val_loss did not improve from 0.04367
# Epoch 65/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2091
#
# Epoch 00065: val_loss did not improve from 0.04367
# Epoch 66/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
# Epoch 00066: val_loss did not improve from 0.04367
# Epoch 67/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0276 - root_mean_squared_error: 0.1663 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2090
#
# Epoch 00067: val_loss improved from 0.04367 to 0.04367, saving model to best_model.h5
# Epoch 68/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2084
#
# Epoch 00068: val_loss improved from 0.04367 to 0.04344, saving model to best_model.h5
# Epoch 69/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0269 - root_mean_squared_error: 0.1640 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2088
#
# Epoch 00069: val_loss did not improve from 0.04344
# Epoch 70/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0267 - root_mean_squared_error: 0.1634 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2083
#
# Epoch 00070: val_loss improved from 0.04344 to 0.04337, saving model to best_model.h5
# Epoch 71/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2077
#
# Epoch 00071: val_loss improved from 0.04337 to 0.04313, saving model to best_model.h5
# Epoch 72/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0267 - root_mean_squared_error: 0.1634 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2076
#
# Epoch 00072: val_loss improved from 0.04313 to 0.04309, saving model to best_model.h5
# Epoch 73/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0270 - root_mean_squared_error: 0.1644 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2075
#
# Epoch 00073: val_loss improved from 0.04309 to 0.04306, saving model to best_model.h5
# Epoch 74/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0430 - val_root_mean_squared_error: 0.2073
#
# Epoch 00074: val_loss improved from 0.04306 to 0.04296, saving model to best_model.h5
# Epoch 75/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650 - val_loss: 0.0430 - val_root_mean_squared_error: 0.2073
#
# Epoch 00075: val_loss improved from 0.04296 to 0.04295, saving model to best_model.h5
# Epoch 76/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0260 - root_mean_squared_error: 0.1613 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2068
#
# Epoch 00076: val_loss improved from 0.04295 to 0.04278, saving model to best_model.h5
# Epoch 77/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0268 - root_mean_squared_error: 0.1637 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2068
#
# Epoch 00077: val_loss did not improve from 0.04278
# Epoch 78/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2062
#
# Epoch 00078: val_loss improved from 0.04278 to 0.04251, saving model to best_model.h5
# Epoch 79/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0259 - root_mean_squared_error: 0.1610 - val_loss: 0.0423 - val_root_mean_squared_error: 0.2057
#
# Epoch 00079: val_loss improved from 0.04251 to 0.04230, saving model to best_model.h5
# Epoch 80/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
#
# Epoch 00080: val_loss improved from 0.04230 to 0.04223, saving model to best_model.h5
# Epoch 81/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0259 - root_mean_squared_error: 0.1609 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2053
#
# Epoch 00081: val_loss improved from 0.04223 to 0.04213, saving model to best_model.h5
# Epoch 82/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658 - val_loss: 0.0423 - val_root_mean_squared_error: 0.2056
#
# Epoch 00082: val_loss did not improve from 0.04213
# Epoch 83/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1628 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2050
#
# Epoch 00083: val_loss improved from 0.04213 to 0.04204, saving model to best_model.h5
# Epoch 84/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1629 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2049
#
# Epoch 00084: val_loss improved from 0.04204 to 0.04198, saving model to best_model.h5
# Epoch 85/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0262 - root_mean_squared_error: 0.1618 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2043
#
# Epoch 00085: val_loss improved from 0.04198 to 0.04175, saving model to best_model.h5
# Epoch 86/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0263 - root_mean_squared_error: 0.1623 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2038
#
# Epoch 00086: val_loss improved from 0.04175 to 0.04154, saving model to best_model.h5
# Epoch 87/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2041
#
# Epoch 00087: val_loss did not improve from 0.04154
# Epoch 88/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0264 - root_mean_squared_error: 0.1626 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2031
#
# Epoch 00088: val_loss improved from 0.04154 to 0.04123, saving model to best_model.h5
# Epoch 89/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0260 - root_mean_squared_error: 0.1613 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
#
# Epoch 00089: val_loss did not improve from 0.04123
# Epoch 90/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2026
#
# Epoch 00090: val_loss improved from 0.04123 to 0.04104, saving model to best_model.h5
# Epoch 91/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0263 - root_mean_squared_error: 0.1623 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2028
#
# Epoch 00091: val_loss did not improve from 0.04104
# Epoch 92/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0260 - root_mean_squared_error: 0.1613 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2028
#
# Epoch 00092: val_loss did not improve from 0.04104
# Epoch 93/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0257 - root_mean_squared_error: 0.1604 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
#
# Epoch 00093: val_loss improved from 0.04104 to 0.04082, saving model to best_model.h5
# Epoch 94/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
#
# Epoch 00094: val_loss did not improve from 0.04082
# Epoch 95/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0258 - root_mean_squared_error: 0.1605 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
#
# Epoch 00095: val_loss did not improve from 0.04082
# Epoch 96/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
#
# Epoch 00096: val_loss improved from 0.04082 to 0.04061, saving model to best_model.h5
# Epoch 97/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0259 - root_mean_squared_error: 0.1611 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2014
#
# Epoch 00097: val_loss improved from 0.04061 to 0.04054, saving model to best_model.h5
# Epoch 98/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0249 - root_mean_squared_error: 0.1580 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2000
#
# Epoch 00098: val_loss improved from 0.04054 to 0.04001, saving model to best_model.h5
# Epoch 99/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0255 - root_mean_squared_error: 0.1597 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1998
#
# Epoch 00099: val_loss improved from 0.04001 to 0.03990, saving model to best_model.h5
# Epoch 100/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0256 - root_mean_squared_error: 0.1601 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1991
#
# Epoch 00100: val_loss improved from 0.03990 to 0.03964, saving model to best_model.h5
# Epoch 101/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0259 - root_mean_squared_error: 0.1609 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1991
#
# Epoch 00101: val_loss did not improve from 0.03964
# Epoch 102/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0253 - root_mean_squared_error: 0.1589 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1987
#
# Epoch 00102: val_loss improved from 0.03964 to 0.03949, saving model to best_model.h5
# Epoch 103/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1985
#
# Epoch 00103: val_loss improved from 0.03949 to 0.03940, saving model to best_model.h5
# Epoch 104/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0263 - root_mean_squared_error: 0.1623 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1995
#
# Epoch 00104: val_loss did not improve from 0.03940
# Epoch 105/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1993
#
# Epoch 00105: val_loss did not improve from 0.03940
# Epoch 106/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1987
#
# Epoch 00106: val_loss did not improve from 0.03940
# Epoch 107/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0258 - root_mean_squared_error: 0.1605 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1984
#
# Epoch 00107: val_loss improved from 0.03940 to 0.03937, saving model to best_model.h5
# Epoch 108/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0255 - root_mean_squared_error: 0.1597 - val_loss: 0.0391 - val_root_mean_squared_error: 0.1977
#
# Epoch 00108: val_loss improved from 0.03937 to 0.03910, saving model to best_model.h5
# Epoch 109/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0258 - root_mean_squared_error: 0.1608 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1973
#
# Epoch 00109: val_loss improved from 0.03910 to 0.03892, saving model to best_model.h5
# Epoch 110/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0388 - val_root_mean_squared_error: 0.1971
#
# Epoch 00110: val_loss improved from 0.03892 to 0.03883, saving model to best_model.h5
# Epoch 111/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1975
#
# Epoch 00111: val_loss did not improve from 0.03883
# Epoch 112/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1973
#
# Epoch 00112: val_loss did not improve from 0.03883
# Epoch 113/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0247 - root_mean_squared_error: 0.1571 - val_loss: 0.0384 - val_root_mean_squared_error: 0.1961
#
# Epoch 00113: val_loss improved from 0.03883 to 0.03844, saving model to best_model.h5
# Epoch 114/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0255 - root_mean_squared_error: 0.1597 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1965
#
# Epoch 00114: val_loss did not improve from 0.03844
# Epoch 115/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1956
#
# Epoch 00115: val_loss improved from 0.03844 to 0.03826, saving model to best_model.h5
# Epoch 116/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1953
#
# Epoch 00116: val_loss improved from 0.03826 to 0.03813, saving model to best_model.h5
# Epoch 117/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0256 - root_mean_squared_error: 0.1599 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1953
#
# Epoch 00117: val_loss did not improve from 0.03813
# Epoch 118/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0380 - val_root_mean_squared_error: 0.1950
#
# Epoch 00118: val_loss improved from 0.03813 to 0.03803, saving model to best_model.h5
# Epoch 119/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0253 - root_mean_squared_error: 0.1590 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1941
#
# Epoch 00119: val_loss improved from 0.03803 to 0.03769, saving model to best_model.h5
# Epoch 120/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596 - val_loss: 0.0378 - val_root_mean_squared_error: 0.1945
#
# Epoch 00120: val_loss did not improve from 0.03769
# Epoch 121/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1580 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1940
#
# Epoch 00121: val_loss improved from 0.03769 to 0.03765, saving model to best_model.h5
# Epoch 122/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0247 - root_mean_squared_error: 0.1571 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1940
#
# Epoch 00122: val_loss improved from 0.03765 to 0.03764, saving model to best_model.h5
# Epoch 123/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0246 - root_mean_squared_error: 0.1569 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1938
#
# Epoch 00123: val_loss improved from 0.03764 to 0.03756, saving model to best_model.h5
# Epoch 124/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0253 - root_mean_squared_error: 0.1590 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1936
#
# Epoch 00124: val_loss improved from 0.03756 to 0.03747, saving model to best_model.h5
# Epoch 125/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0246 - root_mean_squared_error: 0.1570 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1930
#
# Epoch 00125: val_loss improved from 0.03747 to 0.03724, saving model to best_model.h5
# Epoch 126/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0252 - root_mean_squared_error: 0.1586 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1929
#
# Epoch 00126: val_loss improved from 0.03724 to 0.03719, saving model to best_model.h5
# Epoch 127/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1924
#
# Epoch 00127: val_loss improved from 0.03719 to 0.03703, saving model to best_model.h5
# Epoch 128/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0254 - root_mean_squared_error: 0.1592 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1925
#
# Epoch 00128: val_loss did not improve from 0.03703
# Epoch 129/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0246 - root_mean_squared_error: 0.1569 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1928
#
# Epoch 00129: val_loss did not improve from 0.03703
# Epoch 130/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1922
#
# Epoch 00130: val_loss improved from 0.03703 to 0.03693, saving model to best_model.h5
# Epoch 131/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1920
#
# Epoch 00131: val_loss improved from 0.03693 to 0.03685, saving model to best_model.h5
# Epoch 132/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0251 - root_mean_squared_error: 0.1585 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1908
#
# Epoch 00132: val_loss improved from 0.03685 to 0.03641, saving model to best_model.h5
# Epoch 133/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1926
#
# Epoch 00133: val_loss did not improve from 0.03641
# Epoch 134/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0249 - root_mean_squared_error: 0.1577 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1916
#
# Epoch 00134: val_loss did not improve from 0.03641
# Epoch 135/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1911
#
# Epoch 00135: val_loss did not improve from 0.03641
# Epoch 136/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0253 - root_mean_squared_error: 0.1590 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1909
#
# Epoch 00136: val_loss did not improve from 0.03641
# Epoch 137/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
#
# Epoch 00137: val_loss did not improve from 0.03641
# Epoch 138/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1895
#
# Epoch 00138: val_loss improved from 0.03641 to 0.03591, saving model to best_model.h5
# Epoch 139/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1901
#
# Epoch 00139: val_loss did not improve from 0.03591
# Epoch 140/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0246 - root_mean_squared_error: 0.1568 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1902
#
# Epoch 00140: val_loss did not improve from 0.03591
# Epoch 141/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1567 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1898
#
# Epoch 00141: val_loss did not improve from 0.03591
# Epoch 142/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1897
#
# Epoch 00142: val_loss did not improve from 0.03591
# Epoch 143/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1901
#
# Epoch 00143: val_loss did not improve from 0.03591
# Epoch 144/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1551 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1893
#
# Epoch 00144: val_loss improved from 0.03591 to 0.03585, saving model to best_model.h5
# Epoch 145/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0246 - root_mean_squared_error: 0.1568 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1892
#
# Epoch 00145: val_loss improved from 0.03585 to 0.03578, saving model to best_model.h5
# Epoch 146/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1890
#
# Epoch 00146: val_loss improved from 0.03578 to 0.03573, saving model to best_model.h5
# Epoch 147/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0247 - root_mean_squared_error: 0.1570 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1887
#
# Epoch 00147: val_loss improved from 0.03573 to 0.03560, saving model to best_model.h5
# Epoch 148/300
# 165/165 [==============================] - 0s 3ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1883
#
# Epoch 00148: val_loss improved from 0.03560 to 0.03547, saving model to best_model.h5
# Epoch 149/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1883
#
# Epoch 00149: val_loss improved from 0.03547 to 0.03545, saving model to best_model.h5
# Epoch 150/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
#
# Epoch 00150: val_loss improved from 0.03545 to 0.03537, saving model to best_model.h5
# Epoch 151/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1884
#
# Epoch 00151: val_loss did not improve from 0.03537
# Epoch 152/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1891
#
# Epoch 00152: val_loss did not improve from 0.03537
# Epoch 153/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0246 - root_mean_squared_error: 0.1567 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1894
#
# Epoch 00153: val_loss did not improve from 0.03537
# Epoch 154/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1567 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1889
#
# Epoch 00154: val_loss did not improve from 0.03537
# Epoch 155/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1889
#
# Epoch 00155: val_loss did not improve from 0.03537
# Epoch 156/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1885
#
# Epoch 00156: val_loss did not improve from 0.03537
# Epoch 157/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1884
#
# Epoch 00157: val_loss did not improve from 0.03537
# Epoch 158/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1887
#
# Epoch 00158: val_loss did not improve from 0.03537
# Epoch 159/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1879
#
# Epoch 00159: val_loss improved from 0.03537 to 0.03532, saving model to best_model.h5
# Epoch 160/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0243 - root_mean_squared_error: 0.1558 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1874
#
# Epoch 00160: val_loss improved from 0.03532 to 0.03512, saving model to best_model.h5
# Epoch 161/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1554 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1885
#
# Epoch 00161: val_loss did not improve from 0.03512
# Epoch 162/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
#
# Epoch 00162: val_loss did not improve from 0.03512
# Epoch 163/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1873
#
# Epoch 00163: val_loss improved from 0.03512 to 0.03507, saving model to best_model.h5
# Epoch 164/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1877
#
# Epoch 00164: val_loss did not improve from 0.03507
# Epoch 165/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
#
# Epoch 00165: val_loss improved from 0.03507 to 0.03500, saving model to best_model.h5
# Epoch 166/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0246 - root_mean_squared_error: 0.1569 - val_loss: 0.0349 - val_root_mean_squared_error: 0.1868
#
# Epoch 00166: val_loss improved from 0.03500 to 0.03488, saving model to best_model.h5
# Epoch 167/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1877
#
# Epoch 00167: val_loss did not improve from 0.03488
# Epoch 168/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1528 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1870
#
# Epoch 00168: val_loss did not improve from 0.03488
# Epoch 169/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1538 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1867
#
# Epoch 00169: val_loss improved from 0.03488 to 0.03484, saving model to best_model.h5
# Epoch 170/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0243 - root_mean_squared_error: 0.1557 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1865
#
# Epoch 00170: val_loss improved from 0.03484 to 0.03479, saving model to best_model.h5
# Epoch 171/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0243 - root_mean_squared_error: 0.1560 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1867
#
# Epoch 00171: val_loss did not improve from 0.03479
# Epoch 172/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1535 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1861
#
# Epoch 00172: val_loss improved from 0.03479 to 0.03463, saving model to best_model.h5
# Epoch 173/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1861
#
# Epoch 00173: val_loss did not improve from 0.03463
# Epoch 174/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0238 - root_mean_squared_error: 0.1544 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1866
#
# Epoch 00174: val_loss did not improve from 0.03463
# Epoch 175/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1535 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
#
# Epoch 00175: val_loss improved from 0.03463 to 0.03436, saving model to best_model.h5
# Epoch 176/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1867
#
# Epoch 00176: val_loss did not improve from 0.03436
# Epoch 177/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1554 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1856
#
# Epoch 00177: val_loss did not improve from 0.03436
# Epoch 178/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0243 - root_mean_squared_error: 0.1559 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1853
#
# Epoch 00178: val_loss improved from 0.03436 to 0.03435, saving model to best_model.h5
# Epoch 179/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
#
# Epoch 00179: val_loss did not improve from 0.03435
# Epoch 180/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1861
#
# Epoch 00180: val_loss did not improve from 0.03435
# Epoch 181/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1567 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1862
#
# Epoch 00181: val_loss did not improve from 0.03435
# Epoch 182/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1865
#
# Epoch 00182: val_loss did not improve from 0.03435
# Epoch 183/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1860
#
# Epoch 00183: val_loss did not improve from 0.03435
# Epoch 184/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
#
# Epoch 00184: val_loss did not improve from 0.03435
# Epoch 185/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0235 - root_mean_squared_error: 0.1535 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1859
#
# Epoch 00185: val_loss did not improve from 0.03435
# Epoch 186/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
#
# Epoch 00186: val_loss did not improve from 0.03435
# Epoch 187/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
#
# Epoch 00187: val_loss did not improve from 0.03435
# Epoch 188/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1862
#
# Epoch 00188: val_loss did not improve from 0.03435
# Epoch 189/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1865
#
# Epoch 00189: val_loss did not improve from 0.03435
# Epoch 190/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1857
#
# Epoch 00190: val_loss did not improve from 0.03435
# Epoch 191/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1855
#
# Epoch 00191: val_loss did not improve from 0.03435
# Epoch 192/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1852
#
# Epoch 00192: val_loss improved from 0.03435 to 0.03432, saving model to best_model.h5
# Epoch 193/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0243 - root_mean_squared_error: 0.1560 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1856
#
# Epoch 00193: val_loss did not improve from 0.03432
# Epoch 194/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1851
#
# Epoch 00194: val_loss improved from 0.03432 to 0.03426, saving model to best_model.h5
# Epoch 195/300
# ...
# Epoch 234/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
#
# Epoch 00234: val_loss did not improve from 0.03344
# Epoch 235/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1830
#
# Epoch 00235: val_loss did not improve from 0.03344
# Epoch 236/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1835
#
# Epoch 00236: val_loss did not improve from 0.03344
# Epoch 237/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1837
#
# Epoch 00237: val_loss did not improve from 0.03344
# Epoch 238/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1852
#
# Epoch 00238: val_loss did not improve from 0.03344
# Epoch 239/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1553 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1861
#
# Epoch 00239: val_loss did not improve from 0.03344
# Epoch 240/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1846
#
# Epoch 00240: val_loss did not improve from 0.03344
# Epoch 241/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0230 - root_mean_squared_error: 0.1518 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
#
# Epoch 00241: val_loss did not improve from 0.03344
# Epoch 242/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
#
# Epoch 00242: val_loss did not improve from 0.03344
# Epoch 243/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
#
# Epoch 00243: val_loss did not improve from 0.03344
# Epoch 244/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1535 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
#
# Epoch 00244: val_loss did not improve from 0.03344
# Epoch 245/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0244 - root_mean_squared_error: 0.1562 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
#
# Epoch 00245: val_loss did not improve from 0.03344
# Epoch 246/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
#
# Epoch 00246: val_loss did not improve from 0.03344
# Epoch 247/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1843
#
# Epoch 00247: val_loss did not improve from 0.03344
# Epoch 248/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0235 - root_mean_squared_error: 0.1533 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1840
#
# Epoch 00248: val_loss did not improve from 0.03344
# Epoch 249/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0243 - root_mean_squared_error: 0.1560 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
#
# Epoch 00249: val_loss did not improve from 0.03344
# Epoch 250/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0232 - root_mean_squared_error: 0.1523 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
#
# Epoch 00250: val_loss did not improve from 0.03344
# Epoch 251/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1553 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1837
#
# Epoch 00251: val_loss did not improve from 0.03344
# Epoch 252/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
#
# Epoch 00252: val_loss did not improve from 0.03344
# Epoch 253/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1551 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1825
#
# Epoch 00253: val_loss improved from 0.03344 to 0.03330, saving model to best_model.h5
# Epoch 254/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0229 - root_mean_squared_error: 0.1515 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
#
# Epoch 00254: val_loss did not improve from 0.03330
# Epoch 255/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1556 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
#
# Epoch 00255: val_loss did not improve from 0.03330
# Epoch 256/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1554 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1834
#
# Epoch 00256: val_loss did not improve from 0.03330
# Epoch 257/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1832
#
# Epoch 00257: val_loss did not improve from 0.03330
# Epoch 258/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
#
# Epoch 00258: val_loss did not improve from 0.03330
# Epoch 259/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1556 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
#
# Epoch 00259: val_loss did not improve from 0.03330
# Epoch 260/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1830
#
# Epoch 00260: val_loss did not improve from 0.03330
# Epoch 261/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1538 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
#
# Epoch 00261: val_loss did not improve from 0.03330
# Epoch 262/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0244 - root_mean_squared_error: 0.1562 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
#
# Epoch 00262: val_loss did not improve from 0.03330
# Epoch 263/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0231 - root_mean_squared_error: 0.1521 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
#
# Epoch 00263: val_loss did not improve from 0.03330
# Epoch 264/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
#
# Epoch 00264: val_loss did not improve from 0.03330
# Epoch 265/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1830
#
# Epoch 00265: val_loss did not improve from 0.03330
# Epoch 266/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
#
# Epoch 00266: val_loss did not improve from 0.03330
# Epoch 267/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0231 - root_mean_squared_error: 0.1521 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1840
#
# Epoch 00267: val_loss did not improve from 0.03330
# Epoch 268/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
#
# Epoch 00268: val_loss did not improve from 0.03330
# Epoch 269/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1553 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
#
# Epoch 00269: val_loss did not improve from 0.03330
# Epoch 270/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
#
# Epoch 00270: val_loss did not improve from 0.03330
# Epoch 271/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
#
# Epoch 00271: val_loss did not improve from 0.03330
# Epoch 272/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
#
# Epoch 00272: val_loss did not improve from 0.03330
# Epoch 273/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
#
# Epoch 00273: val_loss did not improve from 0.03330
# Epoch 274/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1825
#
# Epoch 00274: val_loss did not improve from 0.03330
# Epoch 275/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0242 - root_mean_squared_error: 0.1554 - val_loss: 0.0334 - val_root_mean_squared_error: 0.1828
#
# Epoch 00275: val_loss did not improve from 0.03330
# Epoch 276/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
#
# Epoch 00276: val_loss did not improve from 0.03330
# Epoch 277/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
#
# Epoch 00277: val_loss did not improve from 0.03330
# Epoch 278/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1837
#
# Epoch 00278: val_loss did not improve from 0.03330
# Epoch 279/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
#
# Epoch 00279: val_loss did not improve from 0.03330
# Epoch 280/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1553 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
#
# Epoch 00280: val_loss did not improve from 0.03330
# Epoch 281/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1535 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
#
# Epoch 00281: val_loss did not improve from 0.03330
# Epoch 282/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0243 - root_mean_squared_error: 0.1558 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1848
#
# Epoch 00282: val_loss did not improve from 0.03330
# Epoch 283/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1837
#
# Epoch 00283: val_loss did not improve from 0.03330
# Epoch 284/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0238 - root_mean_squared_error: 0.1544 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1847
#
# Epoch 00284: val_loss did not improve from 0.03330
# Epoch 285/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
#
# Epoch 00285: val_loss did not improve from 0.03330
# Epoch 286/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1835
#
# Epoch 00286: val_loss did not improve from 0.03330
# Epoch 287/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1574 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
#
# Epoch 00287: val_loss did not improve from 0.03330
# Epoch 288/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0238 - root_mean_squared_error: 0.1541 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1837
#
# Epoch 00288: val_loss did not improve from 0.03330
# Epoch 289/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1840
#
# Epoch 00289: val_loss did not improve from 0.03330
# Epoch 290/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1843
#
# Epoch 00290: val_loss did not improve from 0.03330
# Epoch 291/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
#
# Epoch 00291: val_loss did not improve from 0.03330
# Epoch 292/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
#
# Epoch 00292: val_loss did not improve from 0.03330
# Epoch 293/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
#
# Epoch 00293: val_loss did not improve from 0.03330
# Epoch 294/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1850
#
# Epoch 00294: val_loss did not improve from 0.03330
# Epoch 295/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0238 - root_mean_squared_error: 0.1544 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1846
#
# Epoch 00295: val_loss did not improve from 0.03330
# Epoch 296/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1829
#
# Epoch 00296: val_loss did not improve from 0.03330
# Epoch 297/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1835
#
# Epoch 00297: val_loss did not improve from 0.03330
# Epoch 298/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
#
# Epoch 00298: val_loss did not improve from 0.03330
# Epoch 299/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
#
# Epoch 00299: val_loss did not improve from 0.03330
# Epoch 300/300
# 165/165 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
#
# Epoch 00300: val_loss did not improve from 0.03330
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 2, 32)             4352
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 32)             0
# _________________________________________________________________
# dense (Dense)                (None, 2, 1)              33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model = load_model('best_model.h5')

# %%
y_pred_arr = []
for i in range(0, 20, 1):
    x_test = X_test[i:i+1]
    y_pred = best_model.predict(x_test)
    y_pred_arr.append(y_pred)
y_pred_arr = np.array(y_pred_arr)
y_pred_arr = y_pred_arr.reshape(20, -1)
y_pred_arr.shape
# Out:
# (20, 2)

# %%
y_pred_arr
# Out:
# array([[0.5364326 , 0.60316944],
#        [0.52941245, 0.5218516 ],
#        [0.54104894, 0.46101266],
#        [0.5446465 , 0.59221333],
#        [0.5260862 , 0.44607309],
#        [0.5476733 , 0.65452707],
#        [0.5092818 , 0.5006733 ],
#        [0.54373676, 0.6283893 ],
#        [0.5205472 , 0.43069446],
#        [0.5488165 , 0.540498  ],
#        [0.5298677 , 0.540794  ],
#        [0.5390026 , 0.6461939 ],
#        [0.52112705, 0.60127074],
#        [0.53284013, 0.4952801 ],
#        [0.5431618 , 0.42456156],
#        [0.5471065 , 0.48041147],
#        [0.53999525, 0.6197313 ],
#        [0.52504337, 0.53240085],
#        [0.5404212 , 0.70111746],
#        [0.50918204, 0.41209108]], dtype=float32)

# %%
#y_pred_arr = scaler.inverse_transform(y_pred_arr)
arr = np.zeros(20)
for i in range(len(y_pred_arr)):
    arr[i] = y_pred_arr[i][1]
y_pred_arr = arr[:19]
y_test = y_test[:19]

# %%
#y_test = scaler.inverse_transform(y_test)
compare = np.concatenate((y_test, y_pred_arr), axis = 1)
compare
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 #y_test = scaler.inverse_transform(y_test)
# ----> 2 compare = np.concatenate((y_test, y_pred_arr), axis = 1)
#       3 compare
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
r2 = r2_score(y_test, y_pred_arr)
print (r2)
# Out:
# 0.30525769308229067

# %%
#y_train = scaler.inverse_transform(y_train)
#y_val = scaler.inverse_transform(y_val)

# %%
#pred_data = np.concatenate((y_train, y_val, y_pred_arr), axis = 0)
#pred_data.shape

# %%
#actual_data = np.concatenate((y_train, y_val, y_test), axis = 0)

# %%
#actual_data.shape

# %%
import matplotlib.pyplot as plt
plt.plot(y_pred_arr, label = 'Predicted data')
plt.plot(y_test, label = 'Actual data')
plt.legend()
plt.show()
